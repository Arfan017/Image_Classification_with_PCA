113.jpg', 'face_images\\pic00116.jpg', 'face_images\\pic00117.jpg', 'face_images\\pic00118.jpg', 'face_images\\pic00119.jpg', 'face_images\\pic00121.jpg', 'face_images\\pic00122.jpg', 'face_images\\pic00123.jpg', 'face_images\\pic00124.jpg', 'face_images\\pic00125.jpg', 'face_images\\pic00126.jpg', 'face_images\\pic00127.jpg', 'face_images\\pic00128.jpg', 'face_images\\pic00132.jpg', 'face_images\\pic00133.jpg', 'face_images\\pic00134.jpg', 'face_images\\pic00135.jpg', 'face_images\\pic00136.jpg', 'face_images\\pic00138.jpg', 'face_images\\pic00139.jpg', 'face_images\\pic00142.jpg', 'face_images\\pic00147.jpg', 'face_images\\pic00150.jpg', 'face_images\\pic00152.jpg', 'face_images\\pic00153.jpg', 'face_images\\pic00154.jpg', 'face_images\\pic00156.jpg', 'face_images\\pic00157.jpg', 'face_images\\pic00158.jpg', 'face_images\\pic00160.jpg', 'face_images\\pic00161.jpg', 'face_images\\pic00163.jpg', 'face_images\\pic00165.jpg', 'face_images\\pic00166.jpg', 'face_images\\pic00168.jpg', 'face_images\\pic00171.jpg', 'face_images\\pic00174.jpg', 'face_images\\pic00175.jpg', 'face_images\\pic00176.jpg', 'face_images\\pic00180.jpg', 'face_images\\pic00184.jpg', 'face_images\\pic00187.jpg', 'face_images\\pic00193.jpg', 'face_images\\pic00198.jpg', 'face_images\\pic00200.jpg', 'face_images\\pic00201.jpg', 'face_images\\pic00202.jpg', 'face_images\\pic00203.jpg', 'face_images\\pic00204.jpg', 'face_images\\pic00205.jpg', 'face_images\\pic00207.jpg', 'face_images\\pic00211.jpg', 'face_images\\pic00213.jpg', 'face_images\\pic00214.jpg', 'face_images\\pic00216.jpg', 'face_images\\pic00217.jpg', 'face_images\\pic00218.jpg', 'face_images\\pic00219.jpg ...

# %%
img_file_names = glob.glob(r'face_images/*.jpg')
img_data = []

scale = 0.2
img_size = None

for im_name in img_file_names:
    im = Image.open(im_name).convert('L')
    
    thumbnail_size = (im.size[0] * scale, im.size[1] * scale)
    im.thumbnail(thumbnail_size)
    
    im_3D_array = np.array(im)
    img_size = im_3D_array.shape
    im_1D_array = np.ravel(im_3D_array)
    
    img_data.append(im_1D_array)

print(len(img_data))
img_data = np.array(img_data, dtype=np.uint8).T
# Out:
# 7092
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# f:\DeepLearning\PCA\PCA-Face-Recognition-master\pca-face-recognition.ipynb Cell 4 line 2
#      <a href='vscode-notebook-cell:/f%3A/DeepLearning/PCA/PCA-Face-Recognition-master/pca-face-recognition.ipynb#W3sZmlsZQ%3D%3D?line=16'>17</a>     img_data.append(im_1D_array)
#      <a href='vscode-notebook-cell:/f%3A/DeepLearning/PCA/PCA-Face-Recognition-master/pca-face-recognition.ipynb#W3sZmlsZQ%3D%3D?line=18'>19</a> print(len(img_data))
# ---> <a href='vscode-notebook-cell:/f%3A/DeepLearning/PCA/PCA-Face-Recognition-master/pca-face-recognition.ipynb#W3sZmlsZQ%3D%3D?line=19'>20</a> img_data = np.array(img_data, dtype=np.uint8).T
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (7092,) + inhomogeneous part.

# %%
img_data.shape
# Out:
# Running cells with 'venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'f:/DeepLearning/PCA/PCA-Face-Recognition-master/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
img_size
# Out:
# Running cells with 'venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'f:/DeepLearning/PCA/PCA-Face-Recognition-master/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# ### 2. Step: Compute SVD & plot eigenfaces just for fun

# %%
U, S, Vh = np.linalg.svd(img_data)
# Out:
# Running cells with 'venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'f:/DeepLearning/PCA/PCA-Face-Recognition-master/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
print(U[:, 0])

f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(14, 22))

ax1.imshow((U[:, 0]).reshape(img_size), cmap='gray')
ax2.imshow((U[:, 4]).reshape(img_size), cmap='gray')
ax3.imshow((U[:, 449]).reshape(img_size), cmap='gray')
# Out:
# Running cells with 'venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'f:/DeepLearning/PCA/PCA-Face-Recognition-master/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# ### 3. Step: Project faces onto orthogonal subspace and measure similarity (euclidean distance)
# $P^TX=Y$

# %%
face_proj = U.T @ img_data
# Out:
# Running cells with 'venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'f:/DeepLearning/PCA/PCA-Face-Recognition-master/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
def similarity_between_faces(face1, face2, plot=False):
    if plot:
        f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,18))
        ax1.imshow(img_data[:, face1].reshape(img_size), cmap='gray')
        ax2.imshow(img_data[:, face2].reshape(img_size), cmap='gray')
    
    face_diff = face_proj[:, face1] - face_proj[:, face2]
    
    return np.linalg.norm(face_diff)
# Out:
# Running cells with 'venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'f:/DeepLearning/PCA/PCA-Face-Recognition-master/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
similarity_between_faces(0, 439, plot=True)
# Out:
# Running cells with 'venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'f:/DeepLearning/PCA/PCA-Face-Recognition-master/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
# plot 3 most similar faces
def find_3_most_similar_to(face, plot=False):
    best_scores = [9999999, 9999999, 9999999]
    best_face_i = [0, 0, 0]

    for face_i in range(449):
        sim = similarity_between_faces(face, face_i)
        for i, best_sim in enumerate(best_scores):
            if sim < best_sim:
                best_scores[i] = sim
                best_face_i[i] = face_i
                break
    
    plt.imshow(img_data[:, face].reshape(img_size), cmap='gray')
    plt.title('Compare to this')
    
    f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 18))
    
    ax1.imshow(img_data[:, best_face_i[0]].reshape(img_size), cmap='gray')
    ax1.set_title("Score: {}".format(int(best_scores[0])))
    
    ax2.imshow(img_data[:, best_face_i[1]].reshape(img_size), cmap='gray')
    ax2.set_title("Score: {}".format(int(best_scores[1])))
    
    ax3.imshow(img_data[:, best_face_i[2]].reshape(img_size), cmap='gray')
    ax3.set_title("Score: {}".format(int(best_scores[2])))
    
    return best_face_i, best_scores
# Out:
# Running cells with 'venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'f:/DeepLearning/PCA/PCA-Face-Recognition-master/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
find_3_most_similar_to(310, plot=True)
# Out:
# Running cells with 'venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'f:/DeepLearning/PCA/PCA-Face-Recognition-master/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# ### 4. Step: Save first 400 principal components

# %%
# check how much of the variance is captured by the first 400 P.Cs
np.sum(S[:400]) / np.sum(S)
# Out:
# Running cells with 'venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'f:/DeepLearning/PCA/PCA-Face-Recognition-master/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
np.save('principal-components', U[:, :400])
# Out:
# Running cells with 'venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'f:/DeepLearning/PCA/PCA-Face-Recognition-master/venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
